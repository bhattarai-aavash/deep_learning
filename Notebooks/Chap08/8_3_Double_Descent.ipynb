# %% [markdown]
# <a href="https://colab.research.google.com/github/bhattarai-aavash/deep_learning/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-950f1a8j
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-950f1a8j
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14626 sha256=12486fbf10c354b75b4d0913ba24cb32450b981023292441d0242ffea87f73e3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8na_8cta/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.300456, train error 88.93,  test loss 2.300416, test error 88.80
# Epoch   100, train loss 1.914755, train error 72.82,  test loss 1.759598, test error 70.10
# Epoch   200, train loss 1.907359, train error 71.57,  test loss 1.748896, test error 69.53
# Epoch   300, train loss 1.902012, train error 72.38,  test loss 1.744704, test error 69.12
# Epoch   400, train loss 1.901192, train error 71.12,  test loss 1.735262, test error 69.55
# Epoch   500, train loss 1.900042, train error 71.10,  test loss 1.739177, test error 69.30
# Epoch   600, train loss 1.899688, train error 71.55,  test loss 1.735940, test error 69.12
# Epoch   700, train loss 1.900822, train error 71.78,  test loss 1.738178, test error 69.40
# Epoch   800, train loss 1.897965, train error 71.40,  test loss 1.736716, test error 69.45
# Epoch   900, train loss 1.898991, train error 71.53,  test loss 1.737510, test error 68.88
# Training model with   4 hidden variables
# Epoch     0, train loss 2.272399, train error 88.57,  test loss 2.274423, test error 89.10
# Epoch   100, train loss 1.724573, train error 63.15,  test loss 1.527094, test error 57.88
# Epoch   200, train loss 1.712003, train error 62.30,  test loss 1.507000, test error 58.33
# Epoch   300, train loss 1.707444, train error 61.90,  test loss 1.504400, test error 57.83
# Epoch   400, train loss 1.704344, train error 61.40,  test loss 1.502890, test error 58.45
# Epoch   500, train loss 1.704417, train error 62.12,  test loss 1.507815, test error 58.30
# Epoch   600, train loss 1.701610, train error 61.30,  test loss 1.506183, test error 57.97
# Epoch   700, train loss 1.700859, train error 61.25,  test loss 1.501418, test error 57.67
# Epoch   800, train loss 1.700027, train error 61.45,  test loss 1.508193, test error 58.42
# Epoch   900, train loss 1.690082, train error 61.47,  test loss 1.507702, test error 58.08
# Training model with   6 hidden variables
# Epoch     0, train loss 2.195320, train error 83.00,  test loss 2.175754, test error 82.78
# Epoch   100, train loss 1.684214, train error 60.75,  test loss 1.548962, test error 59.17
# Epoch   200, train loss 1.655230, train error 60.30,  test loss 1.542093, test error 58.67
# Epoch   300, train loss 1.643319, train error 59.53,  test loss 1.544490, test error 58.92
# Epoch   400, train loss 1.640272, train error 59.88,  test loss 1.539384, test error 59.20
# Epoch   500, train loss 1.633993, train error 59.60,  test loss 1.542238, test error 58.97
# Epoch   600, train loss 1.638122, train error 59.83,  test loss 1.542857, test error 58.20
# Epoch   700, train loss 1.630057, train error 59.88,  test loss 1.549614, test error 58.92
# Epoch   800, train loss 1.636012, train error 59.85,  test loss 1.554392, test error 58.80
# Epoch   900, train loss 1.629271, train error 58.88,  test loss 1.547754, test error 58.47
# Training model with   8 hidden variables
# Epoch     0, train loss 2.299367, train error 86.35,  test loss 2.297363, test error 86.43
# Epoch   100, train loss 1.602827, train error 56.55,  test loss 1.425922, test error 55.42
# Epoch   200, train loss 1.550621, train error 54.70,  test loss 1.397501, test error 53.78
# Epoch   300, train loss 1.532001, train error 54.17,  test loss 1.377502, test error 53.28
# Epoch   400, train loss 1.519746, train error 54.58,  test loss 1.386968, test error 53.10
# Epoch   500, train loss 1.511523, train error 53.90,  test loss 1.385256, test error 52.70
# Epoch   600, train loss 1.509380, train error 54.15,  test loss 1.400467, test error 53.30
# Epoch   700, train loss 1.501304, train error 53.38,  test loss 1.397825, test error 53.55
# Epoch   800, train loss 1.498488, train error 52.65,  test loss 1.399287, test error 53.95
# Epoch   900, train loss 1.493510, train error 52.83,  test loss 1.406281, test error 53.10
# Training model with  10 hidden variables
# Epoch     0, train loss 2.236504, train error 84.68,  test loss 2.229025, test error 84.07
# Epoch   100, train loss 1.562250, train error 54.95,  test loss 1.414076, test error 55.10
# Epoch   200, train loss 1.490814, train error 52.47,  test loss 1.394222, test error 53.35
# Epoch   300, train loss 1.459928, train error 50.97,  test loss 1.380806, test error 53.58
# Epoch   400, train loss 1.447199, train error 51.08,  test loss 1.389673, test error 53.72
# Epoch   500, train loss 1.442422, train error 50.60,  test loss 1.408494, test error 54.20
# Epoch   600, train loss 1.436111, train error 50.38,  test loss 1.393993, test error 53.53
# Epoch   700, train loss 1.429763, train error 49.90,  test loss 1.390162, test error 53.20
# Epoch   800, train loss 1.420988, train error 50.00,  test loss 1.392924, test error 53.25
# Epoch   900, train loss 1.415903, train error 49.53,  test loss 1.396231, test error 53.47
# Training model with  14 hidden variables
# Epoch     0, train loss 2.265379, train error 85.32,  test loss 2.273989, test error 85.07
# Epoch   100, train loss 1.466154, train error 50.65,  test loss 1.409092, test error 54.42
# Epoch   200, train loss 1.384889, train error 47.28,  test loss 1.367800, test error 52.03
# Epoch   300, train loss 1.353870, train error 46.20,  test loss 1.374547, test error 51.05
# Epoch   400, train loss 1.337654, train error 46.40,  test loss 1.396644, test error 51.88
# Epoch   500, train loss 1.323130, train error 45.60,  test loss 1.399949, test error 51.50
# Epoch   600, train loss 1.315226, train error 45.83,  test loss 1.410240, test error 51.25
# Epoch   700, train loss 1.299735, train error 44.42,  test loss 1.395696, test error 50.50
# Epoch   800, train loss 1.302759, train error 44.65,  test loss 1.412404, test error 51.08
# Epoch   900, train loss 1.293501, train error 44.35,  test loss 1.407015, test error 50.80
# Training model with  18 hidden variables
# Epoch     0, train loss 2.159722, train error 80.53,  test loss 2.123308, test error 80.45
# Epoch   100, train loss 1.406324, train error 48.47,  test loss 1.388195, test error 52.88
# Epoch   200, train loss 1.314351, train error 43.83,  test loss 1.407330, test error 52.15
# Epoch   300, train loss 1.272851, train error 43.00,  test loss 1.455654, test error 53.10
# Epoch   400, train loss 1.252681, train error 42.72,  test loss 1.486835, test error 53.42
# Epoch   500, train loss 1.224389, train error 41.65,  test loss 1.509209, test error 52.97
# Epoch   600, train loss 1.213897, train error 41.78,  test loss 1.581624, test error 55.45
# Epoch   700, train loss 1.193545, train error 40.17,  test loss 1.612077, test error 54.65
# Epoch   800, train loss 1.180640, train error 39.83,  test loss 1.657961, test error 55.30
# Epoch   900, train loss 1.179671, train error 39.85,  test loss 1.688757, test error 54.88
# Training model with  22 hidden variables
# Epoch     0, train loss 2.192684, train error 80.10,  test loss 2.185503, test error 80.62
# Epoch   100, train loss 1.253675, train error 42.05,  test loss 1.302493, test error 48.65
# Epoch   200, train loss 1.142699, train error 38.35,  test loss 1.369960, test error 48.62
# Epoch   300, train loss 1.092561, train error 37.53,  test loss 1.447866, test error 49.70
# Epoch   400, train loss 1.055633, train error 36.05,  test loss 1.495083, test error 50.05
# Epoch   500, train loss 1.032965, train error 34.93,  test loss 1.536810, test error 50.12
# Epoch   600, train loss 1.027636, train error 35.30,  test loss 1.610602, test error 50.72
# Epoch   700, train loss 1.006386, train error 34.57,  test loss 1.646023, test error 51.45
# Epoch   800, train loss 0.996262, train error 34.07,  test loss 1.671840, test error 51.90
# Epoch   900, train loss 0.984098, train error 33.50,  test loss 1.741626, test error 52.10
# Training model with  26 hidden variables
# Epoch     0, train loss 2.199665, train error 82.78,  test loss 2.166035, test error 82.10
# Epoch   100, train loss 1.192561, train error 39.92,  test loss 1.337987, test error 49.38
# Epoch   200, train loss 1.050045, train error 34.62,  test loss 1.438182, test error 50.70
# Epoch   300, train loss 0.986953, train error 32.32,  test loss 1.546728, test error 51.53
# Epoch   400, train loss 0.946375, train error 31.43,  test loss 1.630334, test error 51.80
# Epoch   500, train loss 0.931283, train error 31.45,  test loss 1.705423, test error 53.03
# Epoch   600, train loss 0.908701, train error 31.00,  test loss 1.848269, test error 53.65
# Epoch   700, train loss 0.890316, train error 30.62,  test loss 1.895063, test error 53.35
# Epoch   800, train loss 0.879028, train error 30.20,  test loss 1.948896, test error 53.05
# Epoch   900, train loss 0.858332, train error 28.82,  test loss 1.962071, test error 52.45
# Training model with  30 hidden variables
# Epoch     0, train loss 2.094592, train error 78.47,  test loss 2.038652, test error 76.10
# Epoch   100, train loss 1.131602, train error 36.05,  test loss 1.366841, test error 49.65
# Epoch   200, train loss 0.940951, train error 30.57,  test loss 1.546417, test error 51.17
# Epoch   300, train loss 0.853203, train error 27.62,  test loss 1.725524, test error 51.75
# Epoch   400, train loss 0.796538, train error 25.65,  test loss 1.869634, test error 53.10
# Epoch   500, train loss 0.780666, train error 26.03,  test loss 2.029088, test error 53.20
# Epoch   600, train loss 0.757029, train error 25.50,  test loss 2.148557, test error 54.35
# Epoch   700, train loss 0.723420, train error 24.40,  test loss 2.282281, test error 55.15
# Epoch   800, train loss 0.700235, train error 23.30,  test loss 2.346951, test error 55.08
# Epoch   900, train loss 0.696730, train error 22.80,  test loss 2.486958, test error 55.08
# Training model with  35 hidden variables
# Epoch     0, train loss 2.178904, train error 81.07,  test loss 2.156681, test error 79.97
# Epoch   100, train loss 1.033384, train error 33.68,  test loss 1.396813, test error 49.60
# Epoch   200, train loss 0.799994, train error 26.38,  test loss 1.737553, test error 53.62
# Epoch   300, train loss 0.688147, train error 23.03,  test loss 2.139458, test error 54.20
# Epoch   400, train loss 0.630458, train error 21.25,  test loss 2.519023, test error 55.90
# Epoch   500, train loss 0.572527, train error 18.60,  test loss 2.780906, test error 56.38
# Epoch   600, train loss 0.537808, train error 18.45,  test loss 3.065657, test error 57.28
# Epoch   700, train loss 0.482354, train error 15.72,  test loss 3.294900, test error 57.47
# Epoch   800, train loss 0.470050, train error 15.85,  test loss 3.547372, test error 57.35
# Epoch   900, train loss 0.491386, train error 17.50,  test loss 3.791480, test error 57.53
# Training model with  40 hidden variables
# Epoch     0, train loss 2.075020, train error 77.60,  test loss 2.024294, test error 76.78
# Epoch   100, train loss 0.897117, train error 29.15,  test loss 1.439638, test error 49.42
# Epoch   200, train loss 0.627070, train error 20.30,  test loss 1.909874, test error 52.75
# Epoch   300, train loss 0.498258, train error 16.65,  test loss 2.551613, test error 55.42
# Epoch   400, train loss 0.422629, train error 14.62,  test loss 3.213493, test error 55.65
# Epoch   500, train loss 0.315631, train error 10.53,  test loss 4.010842, test error 56.67
# Epoch   600, train loss 0.288398, train error 9.50,  test loss 4.774876, test error 56.65
# Epoch   700, train loss 0.306118, train error 11.60,  test loss 5.381979, test error 57.60
# Epoch   800, train loss 0.237479, train error 8.07,  test loss 6.035830, test error 57.45
# Epoch   900, train loss 0.211784, train error 7.20,  test loss 6.692262, test error 57.67
# Training model with  45 hidden variables
# Epoch     0, train loss 2.141171, train error 79.65,  test loss 2.126585, test error 79.57
# Epoch   100, train loss 0.784449, train error 24.10,  test loss 1.553873, test error 51.08
# Epoch   200, train loss 0.479178, train error 14.43,  test loss 2.239765, test error 51.55
# Epoch   300, train loss 0.315908, train error 9.60,  test loss 3.233579, test error 55.10
# Epoch   400, train loss 0.210096, train error 6.35,  test loss 4.469561, test error 55.25
# Epoch   500, train loss 0.159389, train error 5.03,  test loss 5.844731, test error 57.35
# Epoch   600, train loss 0.248913, train error 8.95,  test loss 7.042052, test error 56.35
# Epoch   700, train loss 0.012538, train error 0.00,  test loss 8.087423, test error 57.15
# Epoch   800, train loss 0.008143, train error 0.00,  test loss 8.764959, test error 57.42
# Epoch   900, train loss 0.006067, train error 0.00,  test loss 9.282119, test error 57.22
# Training model with  50 hidden variables
# Epoch     0, train loss 2.054175, train error 76.43,  test loss 2.006881, test error 76.78
# Epoch   100, train loss 0.716489, train error 23.12,  test loss 1.600634, test error 51.75
# Epoch   200, train loss 0.352215, train error 10.97,  test loss 2.599240, test error 53.60
# Epoch   300, train loss 0.142445, train error 3.32,  test loss 4.226579, test error 55.47
# Epoch   400, train loss 0.028293, train error 0.05,  test loss 5.828818, test error 56.40
# Epoch   500, train loss 0.281636, train error 9.20,  test loss 6.719707, test error 56.30
# Epoch   600, train loss 0.006951, train error 0.00,  test loss 7.263923, test error 56.78
# Epoch   700, train loss 0.004848, train error 0.00,  test loss 7.714549, test error 56.92
# Epoch   800, train loss 0.003743, train error 0.00,  test loss 8.057937, test error 56.55
# Epoch   900, train loss 0.003015, train error 0.00,  test loss 8.341027, test error 56.75
# Training model with  55 hidden variables
# Epoch     0, train loss 2.104300, train error 77.22,  test loss 2.048349, test error 76.47
# Epoch   100, train loss 0.593465, train error 17.65,  test loss 1.723327, test error 50.50
# Epoch   200, train loss 0.156479, train error 2.53,  test loss 3.316454, test error 53.85
# Epoch   300, train loss 0.027375, train error 0.00,  test loss 4.940467, test error 54.58
# Epoch   400, train loss 0.012061, train error 0.00,  test loss 5.791310, test error 54.25
# Epoch   500, train loss 0.007421, train error 0.00,  test loss 6.344543, test error 54.42
# Epoch   600, train loss 0.005192, train error 0.00,  test loss 6.742935, test error 54.38
# Epoch   700, train loss 0.003921, train error 0.00,  test loss 7.058390, test error 54.28
# Epoch   800, train loss 0.003123, train error 0.00,  test loss 7.317594, test error 54.20
# Epoch   900, train loss 0.002580, train error 0.00,  test loss 7.537269, test error 54.12
# Training model with  60 hidden variables
# Epoch     0, train loss 2.067774, train error 76.85,  test loss 2.025173, test error 75.62
# Epoch   100, train loss 0.536458, train error 15.20,  test loss 1.669593, test error 50.58
# Epoch   200, train loss 0.108615, train error 1.15,  test loss 3.271322, test error 53.12
# Epoch   300, train loss 0.019756, train error 0.00,  test loss 4.551762, test error 53.45
# Epoch   400, train loss 0.009517, train error 0.00,  test loss 5.212826, test error 53.62
# Epoch   500, train loss 0.005959, train error 0.00,  test loss 5.658707, test error 54.12
# Epoch   600, train loss 0.004285, train error 0.00,  test loss 5.975345, test error 53.78
# Epoch   700, train loss 0.003287, train error 0.00,  test loss 6.225416, test error 54.10
# Epoch   800, train loss 0.002635, train error 0.00,  test loss 6.437152, test error 53.85
# Epoch   900, train loss 0.002187, train error 0.00,  test loss 6.619752, test error 53.90
# Training model with  70 hidden variables
# Epoch     0, train loss 2.011738, train error 74.25,  test loss 1.973772, test error 75.53
# Epoch   100, train loss 0.376224, train error 9.75,  test loss 1.833752, test error 51.20
# Epoch   200, train loss 0.034412, train error 0.00,  test loss 3.359004, test error 52.42
# Epoch   300, train loss 0.011149, train error 0.00,  test loss 4.099655, test error 52.45
# Epoch   400, train loss 0.006184, train error 0.00,  test loss 4.525184, test error 52.35
# Epoch   500, train loss 0.004144, train error 0.00,  test loss 4.816324, test error 52.35
# Epoch   600, train loss 0.003060, train error 0.00,  test loss 5.040308, test error 52.42
# Epoch   700, train loss 0.002399, train error 0.00,  test loss 5.219735, test error 52.45
# Epoch   800, train loss 0.001956, train error 0.00,  test loss 5.368589, test error 52.53
# Epoch   900, train loss 0.001643, train error 0.00,  test loss 5.498596, test error 52.45
# Training model with  80 hidden variables
# Epoch     0, train loss 2.035117, train error 75.68,  test loss 1.977015, test error 76.62
# Epoch   100, train loss 0.241059, train error 4.35,  test loss 2.088311, test error 51.90
# Epoch   200, train loss 0.019924, train error 0.00,  test loss 3.413918, test error 52.97
# Epoch   300, train loss 0.007996, train error 0.00,  test loss 3.958760, test error 52.83
# Epoch   400, train loss 0.004695, train error 0.00,  test loss 4.288352, test error 53.08
# Epoch   500, train loss 0.003235, train error 0.00,  test loss 4.521604, test error 53.10
# Epoch   600, train loss 0.002436, train error 0.00,  test loss 4.698224, test error 53.22
# Epoch   700, train loss 0.001930, train error 0.00,  test loss 4.846075, test error 53.33
# Epoch   800, train loss 0.001589, train error 0.00,  test loss 4.970572, test error 53.42
# Epoch   900, train loss 0.001342, train error 0.00,  test loss 5.078605, test error 53.33
# Training model with  90 hidden variables
# Epoch     0, train loss 2.003625, train error 75.00,  test loss 1.962690, test error 75.28
# Epoch   100, train loss 0.119245, train error 0.53,  test loss 2.174304, test error 50.58
# Epoch   200, train loss 0.013764, train error 0.00,  test loss 3.110937, test error 50.80
# Epoch   300, train loss 0.006200, train error 0.00,  test loss 3.494072, test error 50.85
# Epoch   400, train loss 0.003823, train error 0.00,  test loss 3.736973, test error 51.05
# Epoch   500, train loss 0.002710, train error 0.00,  test loss 3.915384, test error 51.10
# Epoch   600, train loss 0.002069, train error 0.00,  test loss 4.053869, test error 50.88
# Epoch   700, train loss 0.001659, train error 0.00,  test loss 4.168544, test error 50.97
# Epoch   800, train loss 0.001377, train error 0.00,  test loss 4.265459, test error 50.97
# Epoch   900, train loss 0.001171, train error 0.00,  test loss 4.349246, test error 51.08
# Training model with 100 hidden variables
# Epoch     0, train loss 2.003443, train error 74.45,  test loss 1.946608, test error 74.88
# Epoch   100, train loss 0.100128, train error 0.43,  test loss 2.207440, test error 50.50
# Epoch   200, train loss 0.012380, train error 0.00,  test loss 3.087260, test error 50.67
# Epoch   300, train loss 0.005728, train error 0.00,  test loss 3.444179, test error 50.60
# Epoch   400, train loss 0.003571, train error 0.00,  test loss 3.669292, test error 50.47
# Epoch   500, train loss 0.002537, train error 0.00,  test loss 3.831766, test error 50.58
# Epoch   600, train loss 0.001942, train error 0.00,  test loss 3.959355, test error 50.62
# Epoch   700, train loss 0.001560, train error 0.00,  test loss 4.066278, test error 50.72
# Epoch   800, train loss 0.001295, train error 0.00,  test loss 4.155522, test error 50.65
# Epoch   900, train loss 0.001103, train error 0.00,  test loss 4.233575, test error 50.55
# Training model with 120 hidden variables
# Epoch     0, train loss 1.983600, train error 73.93,  test loss 1.895084, test error 72.97
# Epoch   100, train loss 0.050065, train error 0.00,  test loss 2.146222, test error 49.35
# Epoch   200, train loss 0.009622, train error 0.00,  test loss 2.750203, test error 49.58
# Epoch   300, train loss 0.004746, train error 0.00,  test loss 3.026422, test error 49.35
# Epoch   400, train loss 0.003039, train error 0.00,  test loss 3.204095, test error 49.22
# Epoch   500, train loss 0.002188, train error 0.00,  test loss 3.333866, test error 49.35
# Epoch   600, train loss 0.001691, train error 0.00,  test loss 3.437005, test error 49.25
# Epoch   700, train loss 0.001368, train error 0.00,  test loss 3.522520, test error 49.22
# Epoch   800, train loss 0.001142, train error 0.00,  test loss 3.595197, test error 49.22
# Epoch   900, train loss 0.000976, train error 0.00,  test loss 3.657912, test error 49.38
# Training model with 140 hidden variables
# Epoch     0, train loss 1.965366, train error 73.25,  test loss 1.895581, test error 72.95
# Epoch   100, train loss 0.034373, train error 0.00,  test loss 2.136643, test error 49.28
# Epoch   200, train loss 0.007822, train error 0.00,  test loss 2.588392, test error 48.83
# Epoch   300, train loss 0.004012, train error 0.00,  test loss 2.807639, test error 48.85
# Epoch   400, train loss 0.002608, train error 0.00,  test loss 2.952740, test error 48.85
# Epoch   500, train loss 0.001898, train error 0.00,  test loss 3.060908, test error 48.85
# Epoch   600, train loss 0.001476, train error 0.00,  test loss 3.145778, test error 48.80
# Epoch   700, train loss 0.001199, train error 0.00,  test loss 3.217846, test error 48.78
# Epoch   800, train loss 0.001004, train error 0.00,  test loss 3.278651, test error 48.75
# Epoch   900, train loss 0.000861, train error 0.00,  test loss 3.331553, test error 48.85
# Training model with 160 hidden variables
# Epoch     0, train loss 1.952232, train error 71.55,  test loss 1.863995, test error 72.50
# Epoch   100, train loss 0.029174, train error 0.00,  test loss 2.085543, test error 48.35
# Epoch   200, train loss 0.007167, train error 0.00,  test loss 2.487007, test error 48.58
# Epoch   300, train loss 0.003771, train error 0.00,  test loss 2.683258, test error 48.40
# Epoch   400, train loss 0.002478, train error 0.00,  test loss 2.812183, test error 48.25
# Epoch   500, train loss 0.001815, train error 0.00,  test loss 2.909254, test error 48.38
# Epoch   600, train loss 0.001417, train error 0.00,  test loss 2.987667, test error 48.38
# Epoch   700, train loss 0.001154, train error 0.00,  test loss 3.051854, test error 48.30
# Epoch   800, train loss 0.000969, train error 0.00,  test loss 3.107169, test error 48.25
# Epoch   900, train loss 0.000831, train error 0.00,  test loss 3.156260, test error 48.22
# Training model with 180 hidden variables
# Epoch     0, train loss 1.928029, train error 72.60,  test loss 1.858118, test error 74.25
# Epoch   100, train loss 0.024456, train error 0.00,  test loss 2.001001, test error 48.28
# Epoch   200, train loss 0.006584, train error 0.00,  test loss 2.349470, test error 47.90
# Epoch   300, train loss 0.003520, train error 0.00,  test loss 2.528400, test error 48.10
# Epoch   400, train loss 0.002333, train error 0.00,  test loss 2.647854, test error 48.17
# Epoch   500, train loss 0.001716, train error 0.00,  test loss 2.737413, test error 48.17
# Epoch   600, train loss 0.001344, train error 0.00,  test loss 2.809432, test error 48.15
# Epoch   700, train loss 0.001097, train error 0.00,  test loss 2.869749, test error 48.12
# Epoch   800, train loss 0.000922, train error 0.00,  test loss 2.920503, test error 48.08
# Epoch   900, train loss 0.000792, train error 0.00,  test loss 2.965077, test error 48.25
# Training model with 200 hidden variables
# Epoch     0, train loss 1.908974, train error 69.82,  test loss 1.834179, test error 71.60
# Epoch   100, train loss 0.021238, train error 0.00,  test loss 2.048454, test error 48.62
# Epoch   200, train loss 0.006040, train error 0.00,  test loss 2.382597, test error 48.70
# Epoch   300, train loss 0.003287, train error 0.00,  test loss 2.550037, test error 48.62
# Epoch   400, train loss 0.002191, train error 0.00,  test loss 2.664669, test error 48.65
# Epoch   500, train loss 0.001619, train error 0.00,  test loss 2.750822, test error 48.78
# Epoch   600, train loss 0.001272, train error 0.00,  test loss 2.819866, test error 48.67
# Epoch   700, train loss 0.001040, train error 0.00,  test loss 2.876942, test error 48.55
# Epoch   800, train loss 0.000876, train error 0.00,  test loss 2.926563, test error 48.53
# Epoch   900, train loss 0.000754, train error 0.00,  test loss 2.969378, test error 48.65
# Training model with 250 hidden variables
# Epoch     0, train loss 1.888344, train error 68.53,  test loss 1.821493, test error 71.18
# Epoch   100, train loss 0.016601, train error 0.00,  test loss 1.928815, test error 47.70
# Epoch   200, train loss 0.005241, train error 0.00,  test loss 2.186503, test error 47.40
# Epoch   300, train loss 0.002921, train error 0.00,  test loss 2.323116, test error 47.45
# Epoch   400, train loss 0.001973, train error 0.00,  test loss 2.415920, test error 47.45
# Epoch   500, train loss 0.001470, train error 0.00,  test loss 2.487539, test error 47.45
# Epoch   600, train loss 0.001161, train error 0.00,  test loss 2.544392, test error 47.42
# Epoch   700, train loss 0.000953, train error 0.00,  test loss 2.592439, test error 47.45
# Epoch   800, train loss 0.000805, train error 0.00,  test loss 2.634150, test error 47.55
# Epoch   900, train loss 0.000695, train error 0.00,  test loss 2.670772, test error 47.53
# Training model with 300 hidden variables
# Epoch     0, train loss 1.859582, train error 66.50,  test loss 1.809336, test error 69.25
# Epoch   100, train loss 0.014376, train error 0.00,  test loss 1.832164, test error 46.25
# Epoch   200, train loss 0.004823, train error 0.00,  test loss 2.044406, test error 46.33
# Epoch   300, train loss 0.002734, train error 0.00,  test loss 2.159661, test error 46.33
# Epoch   400, train loss 0.001863, train error 0.00,  test loss 2.238472, test error 46.30
# Epoch   500, train loss 0.001394, train error 0.00,  test loss 2.299356, test error 46.25
# Epoch   600, train loss 0.001105, train error 0.00,  test loss 2.348707, test error 46.33
# Epoch   700, train loss 0.000910, train error 0.00,  test loss 2.390343, test error 46.25
# Epoch   800, train loss 0.000770, train error 0.00,  test loss 2.425812, test error 46.30
# Epoch   900, train loss 0.000666, train error 0.00,  test loss 2.457093, test error 46.38
# Training model with 400 hidden variables
# Epoch     0, train loss 1.883136, train error 67.20,  test loss 1.835201, test error 69.88
# Epoch   100, train loss 0.011718, train error 0.00,  test loss 1.765193, test error 45.25
# Epoch   200, train loss 0.004171, train error 0.00,  test loss 1.935035, test error 45.72
# Epoch   300, train loss 0.002416, train error 0.00,  test loss 2.031041, test error 45.50
# Epoch   400, train loss 0.001664, train error 0.00,  test loss 2.097730, test error 45.58
# Epoch   500, train loss 0.001254, train error 0.00,  test loss 2.149319, test error 45.47
# Epoch   600, train loss 0.000999, train error 0.00,  test loss 2.190900, test error 45.40
# Epoch   700, train loss 0.000825, train error 0.00,  test loss 2.225903, test error 45.45
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.256132, test error 45.45
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.282723, test error 45.47

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
